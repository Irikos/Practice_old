# %%
print("Hello, world!")
print("Starting project...")
# Out:
# Hello, world!
# Starting project...

# %%
print("Importing libraries...")
#imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer 
print("Done importing libraries.")
# Out:
# Importing libraries...
# Done importing libraries.

# %%
print("Importing dataset...")
data = pd.read_csv("Crimes - 2001 to present (25th mai 2020).csv", dtype=object)
print("Done importing dataset.")
# Out:
# Importing dataset...
# Done importing dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4899981 entries, 0 to 4899980
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    object
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                object
#  9   Domestic              object
#  10  Beat                  object
#  11  District              object
#  12  Ward                  object
#  13  Community Area        object
#  14  FBI Code              object
#  15  X Coordinate          object
#  16  Y Coordinate          object
#  17  Year                  object
#  18  Updated On            object
#  19  Latitude              object
#  20  Longitude             object
#  21  Location              object
# ...

# %%
data.head()

# %%
# Feature engineering
# 1. Drop unused tables: ID, Case Number, Description, Block, Location, Location Description as we have too much location information
data = data.drop(['ID', 'Case Number', 'X Coordinate', 'Y Coordinate', 'Block', 'Updated On', 'Location', 'Description', 'Location Description'], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4899981 entries, 0 to 4899980
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Date            object
#  1   IUCR            object
#  2   Primary Type    object
#  3   Arrest          object
#  4   Domestic        object
#  5   Beat            object
#  6   District        object
#  7   Ward            object
#  8   Community Area  object
#  9   FBI Code        object
#  10  Year            object
#  11  Latitude        object
#  12  Longitude       object
# dtypes: object(13)
# memory usage: 486.0+ MB

# %%
# We've eliminated 2020 to minimize the risk of possible anomalies happening in 2020 due to Covid-19
data['Year'] = pd.to_numeric(data['Year'])
data = data[(data.Year > 2014) & (data.Year < 2020)]

# %%
data.info()

# %%
# See how many values are null before engineering
data_missing = data.isnull().sum()
print(data_missing)

# %%
perc_missing = round(100 * (data_missing / len(data)), 2)
print(perc_missing)

# %%
# Visualize how many values are null before engineering
plt.figure(figsize=(12, 12))
sns.heatmap(data.isnull(), cbar=True, cmap='Wistia')

# %%
# since the dataset is absolutely immense, we can easily drop the NaN rows. We will do so before sampling
data = data.dropna()

# %%
# Dataset is too huge and takes too long to train on all of it, we're going to sample 100.000. Also, we're going to duplicate the sampled data in order to apply
# supervised and unsupervised algorithms on the same sample
data = data.sample(n=100000)

# %%
# Since we loaded the model with object as dtype (for faster loading), 
# we're going to specify all the types manually
data['DateTime'] = pd.to_datetime(data['Date'])
data['Year'] = data['DateTime'].dt.year
data['Month'] = data['DateTime'].dt.month
data['Day'] = data['DateTime'].dt.day
data['Hour'] = data['DateTime'].dt.hour

data = data.drop(['Date'], axis=1)
data = data.drop(['DateTime'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-1ffcf805d472> in <module>
# ...

# %%
# Convert categorical attributes to Numerical
# data['Case Number'] = pd.factorize(data['Case Number'])[0]
data['IUCR'] = pd.factorize(data['IUCR'])[0]
data['Primary Type'] = pd.factorize(data['Primary Type'])[0]
data['Arrest'] = pd.factorize(data['Arrest'])[0]
data['Domestic'] = pd.factorize(data['Domestic'])[0]
data['Beat'] = pd.factorize(data['Beat'])[0]
data['District'] = pd.factorize(data['District'])[0]
data['Ward'] = pd.factorize(data['Ward'])[0]
data['Community Area'] = pd.factorize(data['Community Area'])[0]
data['FBI Code'] = pd.factorize(data['FBI Code'])[0]
data['Latitude'] = pd.factorize(data['Latitude'])[0]
data['Longitude'] = pd.factorize(data['Longitude'])[0]
# data['Year'] = pd.factorize(data['Year'])[0]
# data['Month'] = pd.factorize(data['Month'])[0]
# data['Day'] = pd.factorize(data['Day'])[0]
# data['Hour'] = pd.factorize(data['Hour'])[0]

# %%
data2 = data.copy()
data2
# Out:
#          IUCR  Primary Type  Arrest  Domestic  Beat  District  Ward  \
# 631625      0             0       0         0     0         0     0
# 605839      1             1       1         0     1         1     1
# 98916       2             2       0         0     2         2     2
# 507199      2             2       0         0     3         3     3
# 385500      3             3       0         0     4         4     4
# ...       ...           ...     ...       ...   ...       ...   ...
# 390306      4             4       1         1   179        15    18
# 748391      9             6       0         0   159         5    33
# 1412910     4             4       0         1   230         4    44
# 562766      6             2       0         0   112         4     4
# 330486     13             8       0         0   142         2    43
#
#          Community Area  FBI Code  Year  Latitude  Longitude  Month  Day  Hour
# ...

# %%
# integer encode
label_encoder = LabelEncoder()
integer_encoded = {}
# data['Case Number'] = label_encoder.fit_transform(data['Case Number'])
data['IUCR'] = label_encoder.fit_transform(data['IUCR'])
data['Primary Type'] = label_encoder.fit_transform(data['Primary Type'])
data['Arrest'] = label_encoder.fit_transform(data['Arrest'])
data['IUCR'] = label_encoder.fit_transform(data['IUCR'])
data['Domestic'] = label_encoder.fit_transform(data['Domestic'])
data['District'] = label_encoder.fit_transform(data['District'])
data['Ward'] = label_encoder.fit_transform(data['Ward'])
data['Community Area'] = label_encoder.fit_transform(data['Community Area'])
data['FBI Code'] = label_encoder.fit_transform(data['FBI Code'])
data['Latitude'] = label_encoder.fit_transform(data['Latitude'])
data['Longitude'] = label_encoder.fit_transform(data['Longitude'])
data['Beat'] = label_encoder.fit_transform(data['Beat'])
# data['Year'] = label_encoder.fit_transform(data['Year'])
# data['Month'] = label_encoder.fit_transform(data['Month'])
# data['Day'] = label_encoder.fit_transform(data['Day'])
# data['Hour'] = label_encoder.fit_transform(data['Hour'])

# %%
onehotencoder = OneHotEncoder(handle_unknown='ignore') 

# test = pd.DataFrame(onehotencoder.fit_transform(data['Primary Type']).toarray())
data['Primary Type']
# Out:
# 844691      0
# 171063      0
# 1086873     1
# 524780      2
# 1062548     3
#            ..
# 867378      5
# 520029     15
# 832731      0
# 1290171     2
# 83599       2
# Name: Primary Type, Length: 100000, dtype: int64

# %%
data.head()
# Out:
#          Case Number  IUCR  Primary Type  Arrest  Domestic  Beat  District  \
# 844691             0     0             0       0         0     0         0
# 171063             1     1             0       0         1     1         1
# 1086873            2     2             1       0         1     2         2
# 524780             3     3             2       1         1     3         3
# 1062548            4     4             3       0         1     4         4
#
#          Ward  Community Area  FBI Code  Year  Latitude  Longitude  Month  \
# 844691      0               0         0     0         0          0      0
# 171063      1               1         0     1         1          1      1
# 1086873     2               2         1     2         2          2      1
# 524780      1               3         2     3         3          3      2
# 1062548     3               4         3     0         4          4      2
#
#          Day  Hour
# 844691     0     0
# 171063     1     1
# ...

# %%
# Convert categorical attributes to Numerical
columnTransformer = ColumnTransformer([('encoder', 
                                        OneHotEncoder(), 
                                        [0])], 
                                      remainder='passthrough') 
onehotencoder = OneHotEncoder() 
data = np.array(columnTransformer.fit_transform(data), dtype = np.str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-01bd14b6b3d5> in <module>
#       5                                       remainder='passthrough')
#       6 onehotencoder = OneHotEncoder()
# ----> 7 data = np.array(columnTransformer.fit_transform(data), dtype = np.str)
#
# ValueError: setting an array element with a sequence

# %%
# new_df = pd.concat([data, pd.get_dummies(data['Case Number'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['IUCR'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['Primary Type'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['Arrest'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['Domestic'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['District'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['Beat'])], axis=1)
new_df = pd.concat([data, pd.get_dummies(data['FBI Code'])], axis=1)

# new_df = data.drop('Case Number', axis=1, inplace=True)
# new_df = data.drop('IUCR', axis=1, inplace=True)
# new_df = data.drop('Primary Type', axis=1, inplace=True)
# new_df = data.drop('Arrest', axis=1, inplace=True)
# new_df = data.drop('Domestic', axis=1, inplace=True)
# new_df = data.drop('District', axis=1, inplace=True)
# new_df = data.drop('Ward', axis=1, inplace=True)
# new_df = data.drop('Beat', axis=1, inplace=True)
# new_df = data.drop('Community Area', axis=1, inplace=True)
# new_df = data.drop('FBI Code', axis=1, inplace=True)
# new_df = data.drop('Latitude', axis=1, inplace=True)
# new_df = data.drop('Longitude', axis=1, inplace=True)
# new_df = data.drop('Year', axis=1, inplace=True)
# new_df = data.drop('Month', axis=1, inplace=True)
# new_df = data.drop('Day', axis=1, inplace=True)
# new_df = data.drop('Hour', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-26-efcbcd7dfcc1> in <module>
# ----> 1 new_df = pd.concat([data, pd.get_dummies(data['Case Number'])], axis=1)
#       2 new_df = pd.concat([data, pd.get_dummies(data['IUCR'])], axis=1)
#       3 new_df = pd.concat([data, pd.get_dummies(data['Primary Type'])], axis=1)
#       4 new_df = pd.concat([data, pd.get_dummies(data['Arrest'])], axis=1)
#       5 new_df = pd.concat([data, pd.get_dummies(data['Domestic'])], axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     932             sparse=sparse,
#     933             drop_first=drop_first,
# --> 934             dtype=dtype,
#     935         )
#     936     return result
#
# ...

# %%
data
# Out:
#          Beat
# 844691     59
# 171063      6
# 1086873   165
# 524780    150
# 1062548   265
# ...       ...
# 867378     62
# 520029    123
# 832731     61
# 1290171   139
# 83599     108
#
# [100000 rows x 1 columns]

# %%
print(new_df)
# Out:
# None

# %%
# Using Pearson correlation
plt.figure(figsize=(18, 10))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# types of crimes
plt.figure(figsize=(12, 12))
sns.countplot(data['Arrest'])
no, yes = data['Arrest'].value_counts()
print("Number of cases ending with arrests:", yes)
print("Number of cases ending without arrests:", no)
# Out:
# Number of cases ending with arrests: 21102
# Number of cases ending without arrests: 78898

# %%
# types of crimes
plt.figure(figsize=(12, 12))
sns.countplot(x='Year', hue='Arrest', data=data)

print("Percentage per year:")
data['Year'].value_counts(normalize=True) * 100
# Out:
# Percentage per year:
# 1    21.138
# 0    21.016
# 2    20.838
# 4    20.307
# 3    16.701
# Name: Year, dtype: float64

# %%
# types of crimes
plt.figure(figsize=(12, 12))
sns.countplot(y="Primary Type", data=data, order=data['Primary Type'].value_counts().iloc[:].index)

# %%
# First, we sum up the amount of Crime Type happened and select the last 13 classes
all_classes = data.groupby(['Primary Type'])['Arrest'].size().reset_index()
all_classes['Amt'] = all_classes['Arrest']
all_classes = all_classes.drop(['Arrest'], axis=1)
all_classes = all_classes.sort_values(['Amt'], ascending=[False])

unwanted_classes = all_classes.tail(15)
unwanted_classes
# After that, we replaced it with label 'OTHERS'
data.loc[data['Primary Type'].isin(unwanted_classes['Primary Type']), 'Primary Type'] = 'OTHERS'
sns.countplot(y="Primary Type", data=data, order=data['Primary Type'].value_counts().iloc[:].index)

# %%
data.Date
# Out:
# 4384556    06/12/2007 10:00:00 PM
# 3944929    06/14/2006 07:30:00 PM
# 3566157    08/04/2005 02:00:00 PM
# 96622      06/30/2019 10:41:00 PM
# 2969137    04/24/2004 08:44:01 AM
#                     ...
# 4169555    12/17/2006 10:00:00 AM
# 2962423    04/20/2004 12:00:00 AM
# 3797339    02/13/2006 12:10:00 AM
# 1119519    03/22/2018 08:00:00 PM
# 1318913    12/20/2018 04:00:00 PM
# Name: Date, Length: 100000, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 2123900 to 2680996
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Case Number     100000 non-null  int64
#  1   IUCR            100000 non-null  int64
#  2   Primary Type    100000 non-null  int64
#  3   Arrest          100000 non-null  int64
#  4   Domestic        100000 non-null  int64
#  5   Beat            100000 non-null  int64
#  6   District        100000 non-null  int64
#  7   Ward            100000 non-null  int64
#  8   Community Area  100000 non-null  int64
#  9   FBI Code        100000 non-null  int64
#  10  Year            100000 non-null  int64
#  11  Latitude        100000 non-null  int64
#  12  Longitude       100000 non-null  int64
#  13  Month           100000 non-null  int64
#  14  Day             100000 non-null  int64
#  15  Hour            100000 non-null  int64
# dtypes: int64(16)
# memory usage: 15.5 MB

# %%
data['Arrest'].value_counts()
# Out:
# 1    78897
# 0    21103
# Name: Arrest, dtype: int64

# %%
plt.plot(data.resample('Y').size())
plt.title('Crimes Count Per Year')
plt.xlabel('Years')
plt.ylabel('Number of Crimes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-0da6932e62b7> in <module>
# ----> 1 plt.plot(data.resample('Y').size())
#       2 plt.title('Crimes Count Per Year')
#       3 plt.xlabel('Years')
#       4 plt.ylabel('Number of Crimes')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8113             base=base,
#    8114             key=on,
# -> 8115             level=level,
#    8116         )
#    8117
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1402
# ...

# %%
data['Arrest'].unique()
# Out:
#                      Arrest  Arrest
# Year
# 1970-01-01 00:33:36       0       0
# 1970-01-01 00:33:37       1       1
# 1970-01-01 00:33:38       1       1
# 1970-01-01 00:33:37       1       1
# 1970-01-01 00:33:38       1       1
# ...                     ...     ...
# 1970-01-01 00:33:39       1       1
# 1970-01-01 00:33:38       0       0
# 1970-01-01 00:33:35       1       1
# 1970-01-01 00:33:35       1       1
# 1970-01-01 00:33:37       1       1
#
# [100000 rows x 2 columns]

# %%
X = data.drop(['Arrest'], axis = 1)
y = data['Arrest']
y = pd.factorize(y)[0]

# %%
# spliting data into training: 50%, validation: 25% and testing: 25%
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size = 0.5, train_size = 0.5, random_state = 42)
X_validation, X_test, y_validation, y_test = train_test_split(X_validation, y_validation, test_size = 0.5, train_size = 0.5, random_state = 42)

# %%
# Number of entries in train, test and validation sets
print('Training data:', len(X_train))
print('Testing data:',len(X_test))
print('Validation data:',len(X_validation))
# Out:
# Training data: 50000
# Testing data: 25000
# Validation data: 25000

# %%
neighborsScore = []
max_score = 0
max_k = 0
for k in range(65, 75):# K-NN
    knn = KNeighborsClassifier(n_neighbors = k, metric='euclidean')
    knn.fit(X_train, y_train)
    y_predict = knn.predict(X_validation)
    score = knn.score(X_validation, y_validation)
    if (score > max_score):
        max_score = score
        max_k = k
    print("Neighbors:", k, "Score:", score)
    neighborsScore.append(score)

print (neighborsScore)
print("Neighbors:", max_k, "Max Score:", max_score)
plt.plot(neighborsScore)
# Out:
# Neighbors: 65 Score: 0.79212
# Neighbors: 66 Score: 0.79204
# Neighbors: 67 Score: 0.79192
# Neighbors: 68 Score: 0.79212
# Neighbors: 69 Score: 0.792
# Neighbors: 70 Score: 0.79208
# Neighbors: 71 Score: 0.7918
# Neighbors: 72 Score: 0.79188
# Neighbors: 73 Score: 0.79172
# Neighbors: 74 Score: 0.79184
# [0.79212, 0.79204, 0.79192, 0.79212, 0.792, 0.79208, 0.7918, 0.79188, 0.79172, 0.79184]
# Neighbors: 65 Max Score: 0.79212

# %%
# Random Forest
# Create Model with configuration
rf_model = RandomForestClassifier(n_estimators=100)

# Model Training
rf_model.fit(X_train, y_train)

# Prediction
result = rf_model.predict(X_test)
ac_sc = accuracy_score(y_test, result)
print(ac_sc)
# Out:
# 0.88508

# %%
0.88528

# %%
# Prediction
result = rf_model.predict(X_validation)
ac_sc = accuracy_score(y_validation, result)
print(ac_sc)
# Out:
# 0.8712

# %%
# SVM
clf = svm.SVC()
clf.fit(X_train, y_train)

# %%
predict = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, predict)
# plot_confusion_matrix(cm,class_names)
cm

# %%
print("the accuracy is : "+str((cm[0][0]+cm[1][1]) / (sum(cm[0]) + sum(cm[1]))))

# %% [markdown]
# #
